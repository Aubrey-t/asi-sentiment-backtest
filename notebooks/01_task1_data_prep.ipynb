# %% [markdown]
# # 01_task1_data_prep
#
# This notebook will be used to explore and clean raw data. Steps:
#
# - Load data from `data/raw/`
# - Standardize date columns
# - Save cleaned dataset to `data/interim/`
